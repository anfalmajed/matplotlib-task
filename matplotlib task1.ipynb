# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('C:\\Users\\User\\Downloads\\Employee Sample Data - Copy (1).xlsx')

# %%
data_array=df.to_numpy()

# %%
transposted_array=np.transpose(data_array)

# %%
storted_array=transposted_array[ : , np.argsort(transposted_array[0])]

# %%
def plot_data(df):
plt.hist2d(df['Job Title'],df['Annual Salary'],bins=(20,20),cmap='Green')
plt.colorbar(label='Density')
plt.xlabel(f'{Job Title}')
plt.ylabel(f'{Annual Salary}')
plt.title(f'Relationship between {Job Title} and {Annual Salary} from Excel data')
plt.grid(True)
plt.show()
# Out:
#   Cell In[13], line 2
#     plt.hist2d(df['Job Title'],df['Annual Salary'],bins=(20,20),cmap='Green')
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
bins = [ 25, 30, 35, 40, 45, 50]
plt.hist(df['Age'], bins=bins, edgecolor='blue',color='White')
# Out:
# (array([120., 124., 113., 113., 193.]),
#  array([25., 30., 35., 40., 45., 50.]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(df['Annual Salary'], bins=15, edgecolor='brown',color='green')
# Out:
# (array([ 87., 136., 136., 156.,  78.,  73.,  43.,  67.,  47.,  43.,  45.,
#          13.,  19.,  17.,  29.]),
#  array([ 40063.        ,  54625.33333333,  69187.66666667,  83750.        ,
#          98312.33333333, 112874.66666667, 127437.        , 141999.33333333,
#         156561.66666667, 171124.        , 185686.33333333, 200248.66666667,
#         214811.        , 229373.33333333, 243935.66666667, 258498.        ]),
#  <BarContainer object of 15 artists>)

# %%
plt.plot(x,y)#This is the first drawing before the modification and additions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plt.plot(x,y)#This is the first drawing before the modification and additions
#
# NameError: name 'x' is not defined

# %%
df['Country'].value_counts().plot(kind='bar',color='green')
sizes=[641,218,139]
plt.figure(figsize=(6,6))

# %%
df['City'].value_counts().plot(kind='bar',color='blue')
sizes_2=[118,113,111,109,99,91,65,55,53,52,46,44,42]
plt.xlabel('City')
plt.ylabel('Number of Employee')
plt.figure(figsize=(6,4))

# %%
df['Ethnicity'].value_counts().plot(kind='bar',color='hotpink')
plt.xlabel('Ethnicity')
plt.ylabel('NUMBER OF EMPLOYEE')
plt.title('Ethnicity')
plt.show()

# %%
df['Job Title'].value_counts().plot(kind='bar',color='brown')
plt.xlabel('Job Title')
plt.ylabel('NUMBER OF EMPLOYEE')
plt.title('Job')
plt.show()

# %%
df['Department'].value_counts().plot(kind='bar',color='yellow')
plt.xlabel('Department')
plt.ylabel('NUMBER OF EMPLOYEE')
plt.title('Department Graph')
plt.show()

# %%
df['Business Unit'].value_counts().plot(kind='bar',color='#4CAF50')
plt.xlabel('Business Unit')
plt.ylabel('NUMBER OF EMPLOYEE')
plt.title('Business Unit Graph')
plt.show()

# %%
df['Bonus %'].value_counts().plot(kind='bar',color='Cyan')
plt.xlabel('Bonus %')
plt.ylabel('NUMBER OF EMPLOYEE')
plt.show()

# %%
plt.hist([df['Annual Salary'], df['Bonus %']], bins=10, label=['Annual Salary','Bonus %'])
plt.xlabel('Annual Salary')
plt.ylabel('Bonus %')
plt.titel(' salary & bouns')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 4
#       2 plt.xlabel('Annual Salary')
#       3 plt.ylabel('Bonus %')
# ----> 4 plt.titel(' salary & bouns')
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'titel'
